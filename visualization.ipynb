-- %%
require 'nn'
require 'cunn'
require 'torch'
require 'nngraph'
require 'windowMat2_nocuda'
require 'yHatMat2_nocuda'
-- require 'windowMat2'
-- require 'yHatMat2'
require 'parsevocab'
require 'distributions'
require 'mixtureCriterionMat'
local LSTMH1 = require 'LSTMH1'
local LSTMHN = require 'LSTMHN'

-- torch.setdefaulttensortype('torch.FloatTensor')
-- change model name here ---
model = torch.load('./alexnet.t7')

-- change test string here --
cu = getOneHotStrs({[1]="jimmy"})

-- %%
--print(cu)
iteration = 1000
x_val = {[1]=0}
y_val = {[1]=0}
e_val = {[1]=0}
w = cu[{{},{1},{}}]:squeeze(2)
--print(w)
lstm_c_h1 = torch.zeros(1, 400)
lstm_h_h1 = torch.zeros(1, 400)
lstm_c_h2 = torch.zeros(1, 400)
lstm_h_h2 = torch.zeros(1, 400)
lstm_c_h3 = torch.zeros(1, 400)
lstm_h_h3 = torch.zeros(1, 400)
kappaprev = torch.zeros(1, 10)

-- %%
function makecov(std, rho)
    covmat = torch.Tensor(2,2)
    covmat[{{1},{1}}] = torch.pow(std[{{1},{1}}], 2)
    covmat[{{1},{2}}] = torch.cmul(torch.cmul(std[{{1},{1}}], std[{{1},{2}}]), rho[{{1},{2}}])
    covmat[{{2},{1}}] = torch.cmul(torch.cmul(std[{{1},{1}}], std[{{1},{2}}]), rho[{{1},{2}}])
    covmat[{{2},{2}}] = torch.pow(std[{{1},{2}}], 2)
    return covmat
end


function getX(input)
    
    e_t = input[{{},{1}}]
    pi_t = input[{{},{2,21}}]
    mu_1_t = input[{{},{22,41}}]
    mu_2_t = input[{{},{42,61}}]
    sigma_1_t = input[{{},{62,81}}]
    sigma_2_t = input[{{},{82,101}}]
    rho_t = input[{{},{102,121}}]
    
    x_3 = torch.Tensor(1)
    x_3 = (x_3:bernoulli(e_t:squeeze())):squeeze()
    
    choice = {}
    
    for k=1,50 do
       table.insert(choice, distributions.cat.rnd(pi_t:squeeze(1)):squeeze()) 
    end
    chosen_pi = torch.multinomial(pi_t, 1):squeeze()
    --print(pi_t)
    --chosen_pi = distributions.cat.rnd(pi_t:squeeze(1)):squeeze()
    
    randChoice = torch.random(50)
    
    max = 0
    for i=1,20 do
        cur = pi_t[{{},{i}}]:squeeze()
        --print(cur)
        if cur > max then
           max = cur 
            index = i
        end
    end
    --chosen_pi = choice[randChoice]
    --print(chosen_pi)
    --chosen_pi=index
    --print(chosen_pi)
    
    curstd = torch.Tensor({{sigma_1_t[{{},{chosen_pi}}]:squeeze(), sigma_2_t[{{},{chosen_pi}}]:squeeze()}})
    curcor = torch.Tensor({{1, rho_t[{{},{chosen_pi}}]:squeeze()}})
    curcovmat = makecov(curstd, curcor)
    curmean = torch.Tensor({{mu_1_t[{{},{chosen_pi}}]:squeeze(), mu_2_t[{{},{chosen_pi}}]:squeeze()}})
    sample = distributions.mvn.rnd(curmean, curcovmat)
    x_1 = sample[1]
    x_2 = sample[2]
    
    table.insert(x_val, x_1)
    table.insert(y_val, x_2)
    table.insert(e_val, x_3)
    --return x_1, x_2, x_3
end

-- %%
model.rnn_core:double();

-- %%
for t=1, 1000 do
    x_in = torch.Tensor({{x_val[t], y_val[t], e_val[t]}})
    
-- model 
    output_y, kappaprev, w, phi, lstm_c_h1, lstm_h_h1,
    lstm_c_h2, lstm_h_h2, lstm_c_h3, lstm_h_h3
    = unpack(model.rnn_core:forward({x_in, cu, 
    kappaprev, w, lstm_c_h1, lstm_h_h1,
    lstm_c_h2, lstm_h_h2, lstm_c_h3, lstm_h_h3}))    
    
    --print(phi:squeeze(1))
    getX(output_y)
    --sum_x_1 = 0
    --sum_x_2 = 0
    --sum_x_3 = 0
    
    --for i = 1, 10 do
      --  x_1, x_2, x_3 = getX(output_y)
       -- sum_x_1 = x_1 + sum_x_1
       -- sum_x_2 = x_2 + sum_x_2
       -- sum_x_3 = x_3 + sum_x_3
    --end
    
    --avg_x_1 = sum_x_1/10
    --print(avg_x_1)
    --avg_x_2 = sum_x_2/10
    --avg_x_3 = torch.round(sum_x_3/10)
    
    --table.insert(x_val, avg_x_1)
    --table.insert(y_val, avg_x_2)
    --table.insert(e_val, avg_x_3)
end

mean_x = 8.1852355051148
mean_y = 0.1242846623983
std_x = 41.557732170832
std_y = 37.03681538566

for t=1,1000 do
    x_val[t] = (x_val[t]*std_x) + mean_x
    y_val[t] = (y_val[t]*std_y) + mean_y
end

r = torch.zeros(2, 200)

rs = {}
new = true
count = 0
i = 0
oldx = 0
oldy = 0
for j=1,1000 do
    i = i + 1
    if new then
        count = count + 1
        table.insert(rs, torch.zeros(2, 1000))
        i = 1
        new = false
    end
    
    if e_val[j] == 1 or j == 1000 then
        new = true
        rs[count] = rs[count][{{},{1,i}}]
    end
    
    newx = oldx + x_val[j]
    newy = oldy - y_val[j] 
    oldx = newx
    oldy = newy
    rs[count][{{1},{i}}] = newx
    rs[count][{{2},{i}}] = newy
    
end

plotter = {}

for i=1,#rs do
    table.insert(plotter, {"test", rs[i][1], rs[i][2], "-"})
end

gnuplot.plot(plotter)
gnuplot.axis({0,5000,0,5000})

-- %%
plotter

-- %%
Plot = require 'itorch.Plot'

-- %%
plot = Plot():line(torch.rand(10),torch.rand(10));
plot:redraw()
-- Out:
-- <script type="text/javascript">
-- $(function() {
--     if (typeof (window._bokeh_onload_callbacks) === "undefined"){
--   window._bokeh_onload_callbacks = [];
--     }
--     function load_lib(url, callback){
--   window._bokeh_onload_callbacks.push(callback);
--   if (window._bokeh_is_loading){
--       console.log("Bokeh: BokehJS is being loaded, scheduling callback at", new Date());
--       return null;
--   }
--   console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", new Date());
--   window._bokeh_is_loading = true;
--   var s = document.createElement('script');
--   s.src = url;
--   s.async = true;
--   s.onreadystatechange = s.onload = function(){
--       Bokeh.embed.inject_css("http://cdn.pydata.org/bokeh-0.7.0.min.css");
--       window._bokeh_onload_callbacks.forEach(function(callback){callback()});
--   };
--   s.onerror = function(){
--       console.warn("failed to load library " + url);
--   };
--   document.getElementsByTagName("head")[0].appendChild(s);
--     }
--
--     bokehjs_url = "http://cdn.pydata.org/bokeh-0.7.0.min.js"
--
--     var elt = document.getElementById("50ab886e-2ffc-4562-c531-022fe52b2fa8");
--     if(elt==null) {
--   console.log("Bokeh: ERROR: autoload.js configured with elementid '50ab886e-2ffc-4562-c531-022fe52b2fa8'"
--         + "but no matching script tag was found. ")
--   return false;
--     }
--
--     if(typeof(Bokeh) !== "undefined") {
--   console.log("Bokeh: BokehJS loaded, going straight to plotting");
--   var modelid = "1b2b02d9-3646-4ab9-caa9-a669ac920aac";
--   var modeltype = "Plot";
--   var all_models = [{"id":"12b1f31e-8f35-47c8-c71e-51a7ac187abf","type":"ColumnDataSource","attributes":{"data":{"y":[0.64113239827566,0.080292894504964,0.45258341752924,0.81131885247305,0.59954385226592,0.58794091152959,0.29858068493195,0.69576245360076,0.31529025430791,0.74788262834772],"x":[0.043244876665995,0.51778749981895,0.11622103583068,0.74550985614769,0.93114967271686,0.34396917163394,0.31186908553354,0.86502021458,0.12245705584064,0.084616430336609]},"column_names":["y","x"],"cont_ranges":{},"discrete_ranges":{},"selected":[],"id":"12b1f31e-8f35-47c8-c71e-51a7ac187abf","doc":null,"tags":[]}},{"id":"1a477802-4c63-4199-c153-7e6b3973fb12","type":"Line","attributes":{"fill_alpha":{"units":"data","value":0.2},"line_alpha":{"units":"data","value":1},"doc":null,"size":{"units":"screen","value":10},"fill_color":{"value":"red"},"line_color":{"value":"red"},"x":{"units":"data","field":"x"},"id":"1a477802-4c63-4199-c153-7e6b3973fb12","y":{"units":"data","field":"y"},"tags":[]}},{"id":"22ad9f2c-f3f4-4470-c459-aaf010f09368","type":"Line","attributes":{"fill_alpha":{"units":"data","value":0.2},"line_alpha":{"units":"data","value":1},"doc":null,"size":{"units":"screen","value":10},"fill_color":{"value":"red"},"line_color":{"value":"red"},"x":{"units":"data","field":"x"},"id":"22ad9f2c-f3f4-4470-c459-aaf010f09368","y":{"units":"data","field":"y"},"tags":[]}},{"id":"2f79d0ae-336f-4b57-cb29-565af26475f4","type":"GlyphRenderer","attributes":{"name":null,"nonselection_glyph":{"type":"Line","id":"22ad9f2c-f3f4-4470-c459-aaf010f09368"},"doc":null,"server_data_source":null,"data_source":{"type":"ColumnDataSource","id":"12b1f31e-8f35-47c8-c71e-51a7ac187abf"},"glyph":{"type":"Line","id":"1a477802-4c63-4199-c153-7e6b3973fb12"},"selection_glyph":null,"id":"2f79d0ae-336f-4b57-cb29-565af26475f4","tags":[]}},{"id":"e0b42cff-87b8-4a28-cad0-9ac042194cb2","type":"DataRange1d","attributes":{"sources":[{"columns":["x"],"source":{"type":"ColumnDataSource","id":"12b1f31e-8f35-47c8-c71e-51a7ac187abf"}}],"id":"e0b42cff-87b8-4a28-cad0-9ac042194cb2","tags":[],"doc":null}},{"id":"10b4e680-057a-4a1f-cafe-dea08590c4af","type":"DataRange1d","attributes":{"sources":[{"columns":["y"],"source":{"type":"ColumnDataSource","id":"12b1f31e-8f35-47c8-c71e-51a7ac187abf"}}],"id":"10b4e680-057a-4a1f-cafe-dea08590c4af","tags":[],"doc":null}},{"id":"b87a236e-39de-4871-c8d4-3339d14ca9fe","type":"ToolEvents","attributes":{"tags":[],"id":"b87a236e-39de-4871-c8d4-3339d14ca9fe","geometries":[],"doc":null}},{"id":"81fcbe51-b5ee-4db9-cdc0-b8a407dd40eb","type":"BasicTickFormatter","attributes":{"id":"81fcbe51-b5ee-4db9-cdc0-b8a407dd40eb","tags":[],"doc":null}},{"id":"dc92eb86-db89-4bee-cb2f-cecbba231d70","type":"BasicTicker","attributes":{"num_minor_ticks":5,"id":"dc92eb86-db89-4bee-cb2f-cecbba231d70","tags":[],"doc":null}},{"id":"fbfc8de8-bb8e-45f2-c544-0110242eab1d","type":"LinearAxis","attributes":{"formatter":{"type":"BasicTickFormatter","id":"81fcbe51-b5ee-4db9-cdc0-b8a407dd40eb"},"ticker":{"type":"BasicTicker","id":"dc92eb86-db89-4bee-cb2f-cecbba231d70"},"plot":{"id":"1b2b02d9-3646-4ab9-caa9-a669ac920aac","type":"Plot","subtype":"Figure"},"axis_label":null,"id":"fbfc8de8-bb8e-45f2-c544-0110242eab1d","doc":null,"tags":[]}},{"id":"3ec781e8-420c-4d75-cdcb-dee6b0d0068c","type":"Grid","attributes":{"dimension":0,"plot":{"id":"1b2b02d9-3646-4ab9-caa9-a669ac920aac","type":"Plot","subtype":"Figure"},"ticker":{"type":"BasicTicker","id":"dc92eb86-db89-4bee-cb2f-cecbba231d70"},"id":"3ec781e8-420c-4d75-cdcb-dee6b0d0068c","doc":null,"tags":[]}},{"id":"d3c40fd8-8b54-4e08-cecf-70e347496f7d","type":"BasicTickFormatter","attributes":{"id":"d3c40fd8-8b54-4e08-cecf-70e347496f7d","tags":[],"doc":null}},{"id":"295bbb71-c767-4e62-cea9-fd82614afb58","type":"BasicTicker","attributes":{"num_minor_ticks":5,"id":"295bbb71-c767-4e62-cea9-fd82614afb58","tags":[],"doc":null}},{"id":"676a8e95-a689-4ce2-ccdf-bc8ad9f32418","type":"LinearAxis","attributes":{"formatter":{"type":"BasicTickFormatter","id":"d3c40 ...
